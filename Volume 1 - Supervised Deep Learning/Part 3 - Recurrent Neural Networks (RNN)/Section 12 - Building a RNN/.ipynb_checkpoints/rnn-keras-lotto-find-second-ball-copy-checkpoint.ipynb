# %% [markdown]
# # Part 1: Data Preprocessing

# %%
# Here we will try to find second ball given data from past 6 lotto and first ball

# Import usual suspects
import numpy as np
import pandas as pd

# %%
# Importing  the training set
pd_training_set = pd.read_csv('Lottery_NY_Lotto_Winning_Numbers__Beginning_2001_without_bonus.csv', header=None)
pd_training_set.head()
# Out:
#     0   1   2   3   4   5
# 0   8  13  26  35  45  51
# 1   1  15  24  31  34  44
# 2   3   8  29  30  31  49
# 3  21  25  39  50  54  59
# 4  15  19  32  38  47  50

# %%
# Training Set
# now add each column of six rows into next 6 rows of first column
two_dim_lotto_array_train = []
# take 300 rows less from total for testing and rest use for training
# for col in pd_training_set.iloc[:-300,:].values:
for col in pd_training_set.iloc[:,:].values:
#     print (col)
    for row in col:
        two_dim_lotto_array_train.append([row])
#         print (row)

# %%
# convert python list into numpy array
training_set_val = np.array(two_dim_lotto_array_train, ndmin=2)

print (type(training_set_val))
print (training_set_val.ndim)
print (training_set_val.shape)
print (training_set_val)
# Out:
# <class 'numpy.ndarray'>
# 2
# (9768, 1)
# [[ 8]
#  [13]
#  [26]
#  ...,
#  [17]
#  [26]
#  [55]]

# %%
# # Now, let's do normalization

# # from sklearn.preprocessing import MinMaxScaler
# # sc = MinMaxScaler()
# # # Accuracy: 0.0317802805365

# from sklearn.preprocessing import MaxAbsScaler
# sc = MaxAbsScaler()
# #  Accuracy: 0.0293846626395



from sklearn.preprocessing import RobustScaler
sc = RobustScaler()
# Accuracy: 0.0377802805365


training_set = sc.fit_transform(training_set_val)
print (training_set)
print (type(training_set))
print (training_set.ndim)
print (training_set.shape)

# # ALSO TRY STANDARDIZATION INSTEAD OF NORMALIZATION

# # from sklearn.preprocessing import StandardScaler
# # sc = StandardScaler()

# # training_set = sc.fit_transform(training_set_val)
# # print (training_set)
# # print (type(training_set))
# # print (training_set.ndim)
# # print (training_set.shape)

# # NO NORMALIZATION
# training_set = training_set_val
# Out:
# [[-0.73333333]
#  [-0.56666667]
#  [-0.13333333]
#  ...,
#  [-0.43333333]
#  [-0.13333333]
#  [ 0.83333333]]
# <class 'numpy.ndarray'>
# 2
# (9768, 1)

# %%
# Creating a data structure with 60 timesteps and t+1 output
X_train = []
y_train = []
for i in range(6, 9768, 6):
    X_train.append(training_set[i-6:i, 0])
    y_train.append(training_set[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Now, Reshaping for keras before training, as it requires 3 dimenions

# changing from 2 to 3 dimension array, by addding time step as 3rd dimension
# corresponds to (batch_size, timesteps, input_dim)
# X_train = np.reshape(X_train,(7967,1,1))

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

print (X_train.shape)
print (X_train)
# Out:
# (1627, 6, 1)
# [[[-0.73333333]
#   [-0.56666667]
#   [-0.13333333]
#   [ 0.16666667]
#   [ 0.5       ]
#   [ 0.7       ]]
#
#  [[-0.96666667]
#   [-0.5       ]
#   [-0.2       ]
#   [ 0.03333333]
#   [ 0.13333333]
#   [ 0.46666667]]
#
#  [[-0.9       ]
#   [-0.73333333]
#   [-0.03333333]
#   [ 0.        ]
#   [ 0.03333333]
#   [ 0.63333333]]
#
#  ...,
#  [[-0.53333333]
#   [-0.5       ]
#   [-0.3       ]
#   [-0.23333333]
#   [ 0.36666667]
#   [ 0.66666667]]
#
#  [[-0.86666667]
#   [-0.5       ]
#   [-0.2       ]
#   [ 0.1       ]
#   [ 0.23333333]
#   [ 0.93333333]]
#
#  [[-0.93333333]
#   [-0.66666667]
#   [ 0.26666667]
#   [ 0.66666667]
#   [ 0.76666667]
#   [ 0.9       ]]]

# %% [markdown]
# # Part 2: Initializing the RNN

# %%
# importing the Keras liabraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %%
# Create a regressor bassed upon sequential RNN
# classifier = Sequential()
# classifier.add(LSTM(units=10, activation='sigmoid', input_shape=(None, 1)))
# classifier.add(Dense(units=1))
regressor = Sequential()
regressor.add(LSTM(output_dim=6, activation='sigmoid', input_shape=(None, 1), return_sequences = True))
regressor.add(LSTM(output_dim=6, activation='sigmoid', return_sequences = True))
regressor.add(LSTM(output_dim=6, activation='sigmoid', return_sequences = True))
regressor.add(LSTM(output_dim=6, activation='sigmoid', return_sequences = True))
regressor.add(LSTM(output_dim=6, activation='sigmoid', return_sequences = True))
regressor.add(LSTM(output_dim=6, activation='sigmoid'))
regressor.add(Dense(output_dim=1))
# Out:
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="sigmoid", input_shape=(None, 1), return_sequences=True, units=6)`
#
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="sigmoid", return_sequences=True, units=6)`
#   import sys
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="sigmoid", return_sequences=True, units=6)`
#
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="sigmoid", return_sequences=True, units=6)`
#   if __name__ == '__main__':
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="sigmoid", return_sequences=True, units=6)`
#   # Remove the CWD from sys.path while we load stuff.
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(activation="sigmoid", units=6)`
#   # This is added back by InteractiveShellApp.init_path()
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1)`
#   if sys.path[0] == '':

# %%
# Now, let' compile our RNN regressor
# classifier.compile(optimizer='rmsprop', loss='categorical_crossentropy')
regressor.compile(optimizer='rmsprop', loss='mean_squared_error')

# %%
# regressor.fit(X_train ,y_train, batch_size=32, epochs=50) with 4 LSTM and time 60 i achieved 0.0219 loss

regressor.fit(X_train ,y_train, batch_size=32, nb_epoch=200)
# Out:
# Epoch 1/200
#   64/1627 [>.............................] - ETA: 4s - loss: 0.0507
# /Users/pankajmathur/anaconda/envs/keras-playground/lib/python3.6/site-packages/keras/models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 2/200
# 1627/1627 [==============================] - 3s - loss: 0.0503
# Epoch 3/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 4/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 5/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 6/200
# 1627/1627 [==============================] - 3s - loss: 0.0504
# Epoch 7/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 8/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 9/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 10/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 11/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 12/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 13/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 14/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 15/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 16/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 17/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 18/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 19/200
# 1627/1627 [==============================] - 3s - loss: 0.0503
# Epoch 20/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 21/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 22/200
# 1627/1627 [==============================] - 4s - loss: 0.0504
# Epoch 23/200
# 1627/1627 [==============================] - 5s - loss: 0.0506
# Epoch 24/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 25/200
# 1627/1627 [==============================] - 4s - loss: 0.0506
# Epoch 26/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 27/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 28/200
# 1627/1627 [==============================] - 3s - loss: 0.0504
# Epoch 29/200
# 1627/1627 [==============================] - 3s - loss: 0.0504
# Epoch 30/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 31/200
# 1627/1627 [==============================] - 4s - loss: 0.0506
# Epoch 32/200
# 1627/1627 [==============================] - 4s - loss: 0.0506
# Epoch 33/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 34/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 35/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 36/200
# 1627/1627 [==============================] - 3s - loss: 0.0504
# Epoch 37/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 38/200
# 1627/1627 [==============================] - 3s - loss: 0.0503
# Epoch 39/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 40/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 41/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 42/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 43/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 44/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 45/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 46/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 47/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 48/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 49/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 50/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 51/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 52/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 53/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 54/200
# 1627/1627 [==============================] - 3s - loss: 0.0506
# Epoch 55/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 56/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 57/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 58/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 59/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 60/200
# 1627/1627 [==============================] - 4s - loss: 0.0503
# Epoch 61/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 62/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 63/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 64/200
# 1627/1627 [==============================] - 4s - loss: 0.0506
# Epoch 65/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 66/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 67/200
# 1627/1627 [==============================] - 4s - loss: 0.0505
# Epoch 68/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch 69/200
# 1627/1627 [==============================] - 3s - loss: 0.0505
# Epoch
# now add each column of six rows into next 6 rows of first column
two_dim_lotto_array_test = []
# take all rows less from total for testing and rest use for training
for col in pd_training_set.iloc[:,:].values:
#     print (col)
    for row in col:
        two_dim_lotto_array_test.append([row])
#         print (row)

# %%
# convert python list into numpy array
testing_set_val = np.array(two_dim_lotto_array_test, ndmin=2)

print (type(testing_set_val))
print (testing_set_val.ndim)
print (testing_set_val.shape)
print (testing_set_val)
# Out:
# <class 'numpy.ndarray'>
# 2
# (9768, 1)
# [[ 8]
#  [13]
#  [26]
#  ...,
#  [17]
#  [26]
#  [55]]

# %%
# NOw let's concatenate training_set with testing_set_val
real_lotto_numbers = testing_set_val
# real_lotto_numbers = np.concatenate((training_set[0:7968], testing_set_val), axis = 0)
print (type(real_lotto_numbers))
print (real_lotto_numbers.ndim)
print (real_lotto_numbers.shape)
# print (real_lotto_numbers)
# Out:
# <class 'numpy.ndarray'>
# 2
# (9768, 1)

# %%
# X_test = real_lotto_numbers[0:7967]
# X_test = sc.fit_transform(X_test)
# print (type(X_test))
# print (X_test.ndim)
# print (X_test.shape)
# print (X_test)
# # in the end inverse fit transform to get normal stock open price back
# # X_test = real_lotto_numbers

scaled_real_lotto_number = sc.fit_transform(real_lotto_numbers)
inputs = []
for i in range(6, 9768):
    inputs.append(scaled_real_lotto_number[i-6:i, 0])

inputs = np.array(inputs)

print (inputs.shape)
# Out:
# (9762, 6)

# %%
inputs = np.reshape(inputs, (inputs.shape[0], inputs.shape[1],1))
print (inputs.shape)
predicted_lotto_numbers = model.predict(inputs)
predicted_lotto_numbers = sc.inverse_transform(predicted_lotto_numbers)

print (type(predicted_lotto_numbers))
print (predicted_lotto_numbers.ndim)
print (predicted_lotto_numbers.shape)
print (predicted_lotto_numbers)
# Out:
# (9762, 6, 1)
# <class 'numpy.ndarray'>
# 2
# (9762, 1)
# [[  6.20102692]
#  [  8.78435135]
#  [ 19.54117966]
#  ...,
#  [ 22.99444962]
#  [ 29.23181343]
#  [ 39.94407272]]

# %%
# same for X_test
y_predicted = np.around(predicted_lotto_numbers)
print (type(y_predicted))
print (y_predicted.ndim)
print (y_predicted.shape)
print (y_predicted)
# Out:
# <class 'numpy.ndarray'>
# 2
# (9762, 1)
# [[  6.]
#  [  9.]
#  [ 20.]
#  ...,
#  [ 23.]
#  [ 29.]
#  [ 40.]]

# %%
real_lotto_numbers = real_lotto_numbers[6:]

# %%
true_predictions = np.equal(y_predicted, real_lotto_numbers)
print (true_predictions)
print ("Accuracy:", np.sum(true_predictions)/np.size(true_predictions))
# Out:
# [[False]
#  [False]
#  [False]
#  ...,
#  [False]
#  [False]
#  [False]]
# Accuracy: 0.0636140135218

# %%
# Part 4: Let's Visualize the results

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(real_lotto_numbers, color='red', label = 'Real Lotto Numbers')
plt.plot(predicted_lotto_numbers, color='blue', label = 'Predicted Lotto Numbers')
plt.title('Lotto Numbers Prediction')
plt.xlabel('Lotto Results')
plt.ylabel('Lotto Numbers')
plt.legend()
plt.show()

# %%
# X_sample = testing_set_val
# X_sample = sc.fit_transform(X_sample)
# print (type(X_sample))
# print (X_sample.ndim)
# print (X_sample.shape)
# print (X_sample)
# # in the end inverse fit transform to get normal stock open price back
# # X_test = real_lotto_numbers

# %%
# # inverse scaled values to get real stock price
# sample_lotto_numbers = np.around(sc.inverse_transform(y_sample))
# print (type(sample_lotto_numbers))
# print (sample_lotto_numbers.ndim)
# print (sample_lotto_numbers.shape)
# print (sample_lotto_numbers)

# %%
# new_shape = real_lotto_numbers.reshape((11396))
# print (type(new_shape))
# print (new_shape.ndim)
# print (new_shape.shape)
# print (new_shape)
                           
real_lotto_numbers_df = pd.Series(real_lotto_numbers.reshape((9762)), name='real_lotto_numbers')
sample_lotto_numbers_df = pd.Series(np.around(predicted_lotto_numbers.reshape((9762))), name='sample_lotto_numbers')
comparison_df = pd.concat([real_lotto_numbers_df, sample_lotto_numbers_df], axis=1)

comparison_df.head(1200)
# Out:
#       real_lotto_numbers  sample_lotto_numbers
# 0                      1                   6.0
# 1                     15                   9.0
# 2                     24                  20.0
# 3                     31                  31.0
# 4                     34                  41.0
# 5                     44                  46.0
# 6                      3                   7.0
# 7                      8                  10.0
# 8                     29                  15.0
# 9                     30                  35.0
# 10                    31                  41.0
# 11                    49                  46.0
# 12                    21                   7.0
# 13                    25                  22.0
# 14                    39                  32.0
# 15                    50                  42.0
# 16                    54                  51.0
# 17                    59                  54.0
# 18                    15                   6.0
# 19                    19                  19.0
# 20                    32                  24.0
# 21                    38                  37.0
# 22                    47                  44.0
# 23                    50                  51.0
# 24                    21                   7.0
# 25                    25                  24.0
# 26                    27                  31.0
# 27                    39                  33.0
# 28                    44                  44.0
# 29                    56                  50.0
# ...                  ...                   ...
# 1170                  29                   5.0
# 1171                  32                  19.0
# 1172                  34                  32.0
# 1173                  37                  39.0
# 1174                  52                  44.0
# 1175                  57                  51.0
# 1176                   5                  11.0
# 1177                  15                  11.0
# 1178                  26                  20.0
# 1179                  51                  32.0
# 1180                  55                  52.0
# 1181                  57                  54.0
# 1182                   7                   5.0
# 1183                  12                  13.0
# 1184                  32                  18.0
# 1185                  37                  37.0
# 1186                  38                  44.0
# 1187                  50                  49.0
# 1188                   6                   7.0
# 1189                  10                  12.0
# 1190                  13                  17.0
# 1191                  31                  23.0
# 1192                  33                  40.0
# 1193                  39                  45.0
# 1194                   3                   8.0
# 1195                  28                  11.0
# 1196                  30                  32.0
# 1197                  37                  37.0
# 1198                  49                  45.0
# 1199                  54                  54.0
#
# [1200 rows x 2 columns]

# %%
comparison_df.tail(1200)
# Out:
#       real_lotto_numbers  sample_lotto_numbers
# 8562                   5                   7.0
# 8563                   8                  11.0
# 8564                  18                  16.0
# 8565                  36                  25.0
# 8566                  48                  44.0
# 8567                  53                  52.0
# 8568                  15                   6.0
# 8569                  16                  20.0
# 8570                  17                  21.0
# 8571                  26                  26.0
# 8572                  49                  36.0
# 8573                  55                  52.0
# 8574                   2                   5.0
# 8575                   9                  10.0
# 8576                  21                  16.0
# 8577                  25                  27.0
# 8578                  45                  36.0
# 8579                  54                  52.0
# 8580                   3                   5.0
# 8581                   6                  11.0
# 8582                  13                  14.0
# 8583                  27                  22.0
# 8584                  31                  37.0
# 8585                  58                  44.0
# 8586                  22                   5.0
# 8587                  23                  19.0
# 8588                  28                  25.0
# 8589                  39                  33.0
# 8590                  51                  44.0
# 8591                  52                  51.0
# ...                  ...                   ...
# 9732                   1                   6.0
# 9733                   4                   9.0
# 9734                  16                  13.0
# 9735                  25                  25.0
# 9736                  29                  36.0
# 9737                  56                  43.0
# 9738                  14                   5.0
# 9739                  15                  19.0
# 9740                  21                  20.0
# 9741                  23                  27.0
# 9742                  41                  34.0
# 9743                  50                  47.0
# 9744                   4                   5.0
# 9745                  15                  12.0
# 9746                  24                  20.0
# 9747                  33                  30.0
# 9748                  37                  42.0
# 9749                  58                  48.0
# 9750                   2                   5.0
# 9751                  10                   9.0
# 9752                  38                  16.0
# 9753                  50                  42.0
# 9754                  53                  51.0
# 9755                  57                  55.0
# 9756                   4                   6.0
# 9757                   7                  11.0
# 9758                  12                  15.0
# 9759                  17                  23.0
# 9760                  26                  29.0
# 9761                  55                  40.0
#
# [1200 rows x 2 columns]

# %%
real_lotto_results = []
predicted_lotto_results = []
for i in range(6, 9762, 6):
    real_lotto_results.append(real_lotto_numbers[i-6:i, 0])
    predicted_lotto_results.append(np.round(predicted_lotto_numbers[i-6:i, 0]))

real_lotto_results = np.array(real_lotto_results)
print (real_lotto_results.shape)
print ("\n real_lotto_results", real_lotto_results)

predicted_lotto_results = np.array(predicted_lotto_results)
print (predicted_lotto_results.shape)
print ("\n predicted_lotto_results", predicted_lotto_results)
# Out:
# (1626, 6)
#
#  real_lotto_results [[ 1 15 24 31 34 44]
#  [ 3  8 29 30 31 49]
#  [21 25 39 50 54 59]
#  ...,
#  [14 15 21 23 41 50]
#  [ 4 15 24 33 37 58]
#  [ 2 10 38 50 53 57]]
# (1626, 6)
#
#  predicted_lotto_results [[  6.   9.  20.  31.  41.  46.]
#  [  7.  10.  15.  35.  41.  46.]
#  [  7.  22.  32.  42.  51.  54.]
#  ...,
#  [  5.  19.  20.  27.  34.  47.]
#  [  5.  12.  20.  30.  42.  48.]
#  [  5.   9.  16.  42.  51.  55.]]

# %%
print (np.sum(real_lotto_results == predicted_lotto_results))

true_matrix = real_lotto_results == predicted_lotto_results
print (true_matrix)
# Out:
# 621
# [[False False False  True False False]
#  [False False False False False False]
#  [False False False False False False]
#  ...,
#  [False False False False False False]
#  [False False False False False False]
#  [False False False False False False]]

# %%
compare_matrix = []
for rl in real_lotto_results:
    for pl in predicted_lotto_results:
        compare_matrix.append(np.array_equal(rl,pl))
print (np.sum(compare_matrix))
# Out:
# 0

# %%
real_lotto_results_df = pd.DataFrame(real_lotto_results)
real_lotto_results_df.head(1200)
# Out:
#        0   1   2   3   4   5
# 0      1  15  24  31  34  44
# 1      3   8  29  30  31  49
# 2     21  25  39  50  54  59
# 3     15  19  32  38  47  50
# 4     21  25  27  39  44  56
# 5      3   8  13  21  33  41
